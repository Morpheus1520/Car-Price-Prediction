# %% [markdown]
# # Car Price Prediction

# %%
import pandas as pd

# %%
df = pd.read_csv(r"car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %% [markdown]
# There are two types of Sellers

# %%
df["Seller_Type"].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df["Transmission"].unique(), df["Owner"].unique()
# Out:
# (array(['Manual', 'Automatic'], dtype=object), array([0, 1, 3], dtype=int64))

# %%
for cols in df.columns[5:]:
    print(df[cols].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
df.columns[3:]
# Out:
# Index(['Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type',
#        'Transmission', 'Owner'],
#       dtype='object')

# %% [markdown]
# Check Missing and Null values

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.Year = 2022 - df.Year

# %%
df.drop(["Car_Name"], axis=1, inplace=True)

# %%
df.rename(columns={"Year":"No_of_Years"}, inplace=True)

# %%
df
# Out:
#      No_of_Years  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0              8           3.35           5.59       27000    Petrol
# 1              9           4.75           9.54       43000    Diesel
# 2              5           7.25           9.85        6900    Petrol
# 3             11           2.85           4.15        5200    Petrol
# 4              8           4.60           6.87       42450    Diesel
# ..           ...            ...            ...         ...       ...
# 296            6           9.50          11.60       33988    Diesel
# 297            7           4.00           5.90       60000    Petrol
# 298           13           3.35          11.00       87934    Petrol
# 299            5          11.50          12.50        9000    Diesel
# 300            6           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %% [markdown]
# ### Convert Categorical features into OneHotEncoding using get_dummies()

# %% [markdown]
# drop_first=True is used to prevent from falling into the [Dummy Variable Trap](https://www.learndatasci.com/glossary/dummy-variable-trap/)

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.head()
# Out:
#    No_of_Years  Selling_Price  Present_Price  Kms_Driven  Owner  \
# 0            8           3.35           5.59       27000      0
# 1            9           4.75           9.54       43000      0
# 2            5           7.25           9.85        6900      0
# 3           11           2.85           4.15        5200      0
# 4            8           4.60           6.87       42450      0
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
 df.corr()
# Out:
#                         No_of_Years  Selling_Price  Present_Price  Kms_Driven  \
# No_of_Years                1.000000      -0.236141       0.047584    0.524342
# Selling_Price             -0.236141       1.000000       0.878983    0.029187
# Present_Price              0.047584       0.878983       1.000000    0.203647
# Kms_Driven                 0.524342       0.029187       0.203647    1.000000
# Owner                      0.182104      -0.088344       0.008057    0.089216
# Fuel_Type_Diesel          -0.064315       0.552339       0.473306    0.172515
# Fuel_Type_Petrol           0.059959      -0.540571      -0.465244   -0.172874
# Seller_Type_Individual     0.039896      -0.550724      -0.512030   -0.101419
# Transmission_Manual       -0.000394      -0.367128      -0.348715   -0.162510
#
#                            Owner  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# No_of_Years             0.182104         -0.064315          0.059959
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %% [markdown]
# Plotting Heat Map

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))
g = sns.heatmap(df.corr(),annot=True, cmap="RdYlGn", annot_kws={"size": 20})

# %% [markdown]
# Reordering the columns to extract X and y

# %%
df = df[['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'No_of_Years',
       'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
       'Transmission_Manual']]

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  No_of_Years  \
# 0             3.35           5.59       27000      0            8
# 1             4.75           9.54       43000      0            9
# 2             7.25           9.85        6900      0            5
# 3             2.85           4.15        5200      0           11
# 4             4.60           6.87       42450      0            8
# ..             ...            ...         ...    ...          ...
# 296           9.50          11.60       33988      0            6
# 297           4.00           5.90       60000      0            7
# 298           3.35          11.00       87934      0           13
# 299          11.50          12.50        9000      0            5
# 300           5.30           5.90        5464      0            6
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# ...

# %%
X = df.iloc[:, 1:]
y = df.iloc[:, 0]

# %%
# Feature Importance
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X, y)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([0.35708076, 0.04449838, 0.00086883, 0.07535971, 0.23034261,
#        0.01070459, 0.1428376 , 0.13830752])

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  No_of_Years  Fuel_Type_Diesel  \
# 0           5.59       27000      0            8                 0
# 1           9.54       43000      0            9                 1
# 2           9.85        6900      0            5                 0
# 3           4.15        5200      0           11                 0
# 4           6.87       42450      0            8                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
feature_importance = pd.Series(model.feature_importances_, index=X.columns)
feature_importance.nlargest(5).plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train.shape
# Out:
# (240, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random = RandomForestRegressor()

# %%
# Hyperparameters
import numpy as np
n_estimators=[int(x) for x in np.linspace(100, 1200, 12)]
max_features = ["auto", "sqrt"]
max_depth = [int(x) for x in np.linspace(5, 30, 6)]

min_samples_split = [2,5,10,15,100]

min_samples_leaf = [1,2,5,10]

# %%
from sklearn.model_selection import RandomizedSearchCV

random_grid = {"n_estimators": n_estimators,
              "max_features": max_features,
              "max_depth": max_depth,
              "min_samples_split": min_samples_split,
              "min_samples_leaf": min_samples_leaf}

random_grid
# Out:
# {'n_estimators': [100,
#   200,
#   300,
#   400,
#   500,
#   600,
#   700,
#   800,
#   900,
#   1000,
#   1100,
#   1200],
#  'max_features': ['auto', 'sqrt'],
#  'max_depth': [5, 10, 15, 20, 25, 30],
#  'min_samples_split': [2, 5, 10, 15, 100],
#  'min_samples_leaf': [1, 2, 5, 10]}

# %%
model_random = RandomizedSearchCV(estimator= rf_random,
                                  param_distributions=random_grid, 
                                  scoring='neg_mean_squared_error',
                                  n_iter=10, cv=5, verbose=2, random_state=42, n_jobs=1)

# %%
model_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   0.5s
# ...

# %%
model_random.best_params_
# Out:
# {'n_estimators': 700,
#  'min_samples_split': 15,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 20}

# %%
model_random.best_score_
# Out:
# -3.81122497497484

# %%
predictions=model_random.predict(X_test)

# %%
predictions
# Out:
# array([ 5.47687988,  5.14034693,  7.51762646,  0.41823334,  3.02512931,
#         3.29017367,  7.98639159,  7.36446183,  5.09722922,  0.4518577 ,
#         8.12007248,  4.81498954,  1.1971001 ,  4.58810262, 22.91456873,
#         4.92044425,  3.04534666, 10.880679  ,  0.38361047,  5.32532919,
#        10.51465338,  5.0904755 ,  1.17846853,  5.47754726,  5.83447455,
#         0.65884853,  0.39796199, 23.17146786,  4.51631891,  5.3280556 ,
#         0.42107276, 10.86835547,  0.45489451,  4.4888078 ,  5.1088018 ,
#         1.17846853, 10.42651042,  2.96248061, 10.29322655,  0.33154664,
#         1.1801424 ,  0.51117625, 22.91456873,  0.60261639,  7.63398076,
#         0.64512194,  4.4699362 ,  7.93435209,  5.21948001,  4.56879076,
#         0.60301055,  5.29721357,  1.17179663,  2.7361553 ,  1.17281449,
#         0.44789106,  7.04967667,  4.57785016,  2.69503161,  0.55721877,
#         0.242788  ])

# %% [markdown]
# Normal Distribution signifies prediction is good!

# %%
sns.displot(y_test - predictions)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, predictions)
# Out:
# 2.93948466175359

# %%
import pickle

# Open a file where you want to store the data
file = open("random_forest_regression_model.pkl", "wb")
 
# Dump
pickle.dump(model_random, file)
